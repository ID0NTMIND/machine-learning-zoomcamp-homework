# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_fuel_efficiency.csv')

# %%
df.shape
# Out:
# (9704, 11)

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
df.fuel_type.describe()
# Out:
# count         9704
# unique           2
# top       Gasoline
# freq          4898
# Name: fuel_type, dtype: object

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.groupby('origin').fuel_efficiency_mpg.max().round(2)
# Out:
# origin
# Asia      23.76
# Europe    25.97
# USA       24.97
# Name: fuel_efficiency_mpg, dtype: float64

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
horsepower_avg = df.horsepower.mean().round(2)
horsepower_avg
# Out:
# np.float64(149.66)

# %%
horsepower_mode = df.horsepower.mode()[0]
horsepower_mode
# Out:
# np.float64(152.0)

# %%
df.horsepower = df.horsepower.fillna(value=horsepower_mode)

# %%
horsepower_mode = df.horsepower.mode()
horsepower_mode
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
horsepower_avg = df.horsepower.mean().round(2)
horsepower_avg
# Out:
# np.float64(149.83)

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower               0
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0       152.0     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %%
cars_from_asia = df[df.origin == 'Asia']
cars_from_asia = cars_from_asia[['vehicle_weight', 'model_year']].head(7)
cars_from_asia
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %%
X = cars_from_asia.values
Xt = X.T
XTX = Xt.dot(X)

# %%
XTX
# Out:
# array([[62248334.33150762, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 5.71497081e-07, -8.34509443e-07],
#        [-8.34509443e-07,  1.25380877e-06]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100, 1200])

# %%
W = XTX_inv.dot(Xt).dot(y)

# %%
W.sum().round(2)
# Out:
# np.float64(0.52)
